# %% [markdown]
# # Import Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style='white', context='notebook', palette='deep')

import tensorflow as tf
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, losses
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Model

np.random.seed(2)
sns.set(style='white', context='notebook', palette='deep')

# %% [markdown]
# # Data Preparation

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data(path='mnist.npz')
x_train = x_train/255
x_test = x_test/255
print(x_train.shape, x_test.shape)
# Out:
# (60000, 28, 28) (10000, 28, 28)

# %% [markdown]
# # Reduce Unit Size from 784 to 200

# %%
latent_dim = 200

class Autoencoder1(Model):
  def __init__(self, latent_dim):
    super(Autoencoder1, self).__init__()
    self.latent_dim1 = latent_dim   
    self.encoder1 = tf.keras.Sequential([
      layers.Flatten(),
      layers.Dense(latent_dim, activation='relu'),
    ])
    self.decoder1 = tf.keras.Sequential([
      layers.Dense(784, activation='relu'),
      layers.Reshape((28, 28))
    ])

  def call(self, x):
    encoded1 = self.encoder1(x)
    decoded1 = self.decoder1(encoded1)
    return decoded1

autoencoder1 = Autoencoder1(latent_dim)

# %%
autoencoder1.compile(optimizer='RMSprop', loss=losses.MeanSquaredError(), metrics=['accuracy'])

autoencoder1.fit(x_train, x_train,
                epochs=100,
                batch_size=100,
                shuffle=True,
                validation_split=0.3)
# Out:
# Epoch 1/100
# 420/420 [==============================] - 11s 21ms/step - loss: 0.0301 - accuracy: 0.4149 - val_loss: 0.0127 - val_accuracy: 0.5506
# Epoch 2/100
# 420/420 [==============================] - 4s 10ms/step - loss: 0.0116 - accuracy: 0.5515 - val_loss: 0.0104 - val_accuracy: 0.5712
# Epoch 3/100
# 420/420 [==============================] - 4s 10ms/step - loss: 0.0099 - accuracy: 0.5726 - val_loss: 0.0090 - val_accuracy: 0.5898
# Epoch 4/100
# 420/420 [==============================] - 4s 10ms/step - loss: 0.0090 - accuracy: 0.5835 - val_loss: 0.0093 - val_accuracy: 0.6007
# Epoch 5/100
# 420/420 [==============================] - 4s 10ms/step - loss: 0.0085 - accuracy: 0.5898 - val_loss: 0.0082 - val_accuracy: 0.5934
# Epoch 6/100
# 420/420 [==============================] - 4s 10ms/step - loss: 0.0083 - accuracy: 0.5922 - val_loss: 0.0067 - val_accuracy: 0.6012
# Epoch 7/100
# 420/420 [==============================] - 4s 10ms/step - loss: 0.0075 - accuracy: 0.5935 - val_loss: 0.0077 - val_accuracy: 0.5954
# Epoch 8/100
# 420/420 [==============================] - 3s 8ms/step - loss: 0.0074 - accuracy: 0.5959 - val_loss: 0.0073 - val_accuracy: 0.5984
# Epoch 9/100
# 420/420 [==============================] - 4s 9ms/step - loss: 0.0071 - accuracy: 0.5968 - val_loss: 0.0066 - val_accuracy: 0.6103
# Epoch 10/100
# 420/420 [==============================] - 4s 10ms/step - loss: 0.0070 - accuracy: 0.5993 - val_loss: 0.0075 - val_accuracy: 0.5863
# Epoch 11/100
# 420/420 [==============================] - 4s 10ms/step - loss: 0.0069 - accuracy: 0.6001 - val_loss: 0.0066 - val_accuracy: 0.6184
# Epoch 12/100
# 420/420 [==============================] - 4s 10ms/step - loss: 0.0067 - accuracy: 0.6017 - val_loss: 0.0061 - val_accuracy: 0.6162
# Epoch 13/100
# 420/420 [==============================] - 4s 10ms/step - loss: 0.0067 - accuracy: 0.6008 - val_loss: 0.0059 - val_accuracy: 0.6155
# Epoch 14/100
# 420/420 [==============================] - 4s 10ms/step - loss: 0.0066 - accuracy: 0.6021 - val_loss: 0.0068 - val_accuracy: 0.6012
# Epoch 15/100
# 420/420 [==============================] - 4s 10ms/step - loss: 0.0066 - accuracy: 0.6020 - val_loss: 0.0069 - val_accuracy: 0.6122
# Epoch 16/100
# 420/420 [==============================] - 4s 10ms/step - loss: 0.0065 - accuracy: 0.6025 - val_loss: 0.0066 - val_accuracy: 0.6189
# Epoch 17/100
# 420/420 [==============================] - 4s 10ms/step - loss: 0.0065 - accuracy: 0.6032 - val_loss: 0.0067 - val_accuracy: 0.6162
# Epoch 18/100
# 420/420 [==============================] - 5s 11ms/step - loss: 0.0064 - accuracy: 0.6044 - val_loss: 0.0082 - val_accuracy: 0.5974
# Epoch 19/100
# 420/420 [==============================] - 4s 11ms/step - loss: 0.0064 - accuracy: 0.6041 - val_loss: 0.0061 - val_accuracy: 0.6077
# Epoch 20/100
# 420/420 [==============================] - 5s 11ms/step - loss: 0.0063 - accuracy: 0.6045 - val_loss: 0.0067 - val_accuracy: 0.6014
# Epoch 21/100
# 420/420 [==============================] - 4s 10ms/step - loss: 0.0063 - accuracy: 0.6050 - val_loss: 0.0061 - val_accuracy: 0.6131
# Epoch 22/100
# 420/420 [==============================] - 4s 10ms/step - loss: 0.0063 - accuracy: 0.6036 - val_loss: 0.0070 - val_accuracy: 0.6078
# Epoch 23/100
# 420/420 [==============================] - 4s 9ms/step - loss: 0.0062 - accuracy: 0.6052 - val_loss: 0.0056 - val_accuracy: 0.6002
# Epoch 24/100
# 420/420 [==============================] - 4s 10ms/step - loss: 0.0062 - accuracy: 0.6045 - val_loss: 0.0057 - val_accuracy: 0.6261
# Epoch 25/100
# 420/420 [==============================] - 4s 10ms/step - loss: 0.0062 - accuracy: 0.6050 - val_loss: 0.0057 - val_accuracy: 0.6197
# Epoch 26/100
# 420/420 [==============================] - 4s 10ms/step - loss: 0.0061 - accuracy: 0.6060 - val_loss: 0.0059 - val_accuracy: 0.6051
# Epoch 27/100
# 420/420 [==============================] - 4s 10ms/step - loss: 0.0061 - accuracy: 0.6055 - val_loss: 0.0051 - val_accuracy: 0.6198
# Epoch 28/100
# 420/420 [==============================] - 4s 10ms/step - loss: 0.0060 - accuracy: 0.6057 - val_loss: 0.0061 - val_accuracy: 0.6235
# Epoch 29/100
# 420/420 [==============================] - 4s 10ms/step - loss: 0.0061 - accuracy: 0.6056 - val_loss: 0.0070 - val_accuracy: 0.6146
# Epoch 30/100
# 420/420 [==============================] - 4s 10ms/step - loss: 0.0051 - accuracy: 0.6108 - val_loss: 0.0047 - val_accuracy: 0.6274
# Epoch 88/100
# 420/420 [==============================] - 4s 11ms/step - loss: 0.0051 - accuracy: 0.6093 - val_loss: 0.0049 - val_accuracy: 0.6046
# Epoch 89/100
# 420/420 [==============================] - 4s 10ms/step - loss: 0.0051 - accuracy: 0.6099 - val_loss: 0.0054 - val_accuracy: 0.5973
# Epoch 90/100
# 420/420 [==============================] - 4s 10ms/step - loss: 0.0051 - accuracy: 0.6098 - val_loss: 0.0050 - val_accuracy: 0.6175
# Epoch 91/100
# 420/420 [==============================] - 4s 10ms/step - loss: 0.0052 - accuracy: 0.6100 - val_loss: 0.0048 - val_accuracy: 0.6180
# Epoch 92/100
# 420/420 [==============================] - 4s 10ms/step - loss: 0.0051 - accuracy: 0.6101 - val_loss: 0.0047 - val_accuracy: 0.6146
# Epoch 93/100
# 420/420 [==============================] - 4s 10ms/step - loss: 0.0051 - accuracy: 0.6097 - val_loss: 0.0052 - val_accuracy: 0.6209
# Epoch 94/100
# 420/420 [==============================] - 4s 10ms/step - loss: 0.0051 - accuracy: 0.6115 - val_loss: 0.0053 - val_accuracy: 0.6252
# Epoch 95/100
# 420/420 [==============================] - 4s 10ms/step - loss: 0.0051 - accuracy: 0.6101 - val_loss: 0.0051 - val_accuracy: 0.6260
# Epoch 96/100
# 420/420 [==============================] - 4s 10ms/step - loss: 0.0051 - accuracy: 0.6106 - val_loss: 0.0048 - val_accuracy: 0.6220
# Epoch 97/100
# 420/420 [==============================] - 4s 10ms/step - loss: 0.0051 - accuracy: 0.6107 - val_loss: 0.0054 - val_accuracy: 0.6267
# Epoch 98/100
# 420/420 [==============================] - 5s 11ms/step - loss: 0.0051 - accuracy: 0.6080 - val_loss: 0.0051 - val_accuracy: 0.6091
# Epoch 99/100
# 420/420 [==============================] - 4s 11ms/step - loss: 0.0051 - accuracy: 0.6097 - val_loss: 0.0049 - val_accuracy: 0.6128
# Epoch 100/100
# 420/420 [==============================] - 4s 10ms/step - loss: 0.0051 - accuracy: 0.6098 - val_loss: 0.0051 - val_accuracy: 0.6092

# %%
plt.plot(autoencoder1.history.history['val_accuracy'])

# %%
encoded_imgs = autoencoder1.encoder1(x_test).numpy()
decoded_imgs = autoencoder1.decoder1(encoded_imgs).numpy()

# %%
n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
  # display original
  ax = plt.subplot(3, n, i + 1)
  plt.imshow(x_test[i])
  plt.title("original")
  plt.gray()
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

  # display encoded images
  ax = plt.subplot(3, n, i + 1 + n)
  plt.imshow(encoded_imgs[i].reshape(20,10))
  plt.title("encoded")
  plt.gray()
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

  # display reconstruction
  ax = plt.subplot(3, n, i + 1 + n*2)
  plt.imshow(decoded_imgs[i])
  plt.title("reconstructed")
  plt.gray()
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

plt.show()

# %%
for layer in autoencoder1.layers:
    weights = layer.get_weights()
    
fig, axs = plt.subplots(2, 3)
axs[0, 0].imshow(weights[0][0].reshape(28, 28))
axs[0, 1].imshow(weights[0][7].reshape(28, 28))
axs[0, 2].imshow(weights[0][25].reshape(28, 28))
axs[1, 0].imshow(weights[0][93].reshape(28, 28))
axs[1, 1].imshow(weights[0][100].reshape(28, 28))
axs[1, 2].imshow(weights[0][120].reshape(28, 28))

plt.show()

# %% [markdown]
# # Reduce Unit Size from 200 to 45

# %%
latent_dim = 45

class Autoencoder2(Model):
  def __init__(self, latent_dim):
    super(Autoencoder2, self).__init__()
    self.latent_dim2 = latent_dim   
    self.encoder2 = tf.keras.Sequential([
      layers.Flatten(),
      layers.Dense(latent_dim, activation='relu'),
    ])
    self.decoder2 = tf.keras.Sequential([
      layers.Dense(200, activation='relu'),
      layers.Reshape((20, 10))
    ])

  def call(self, x):
    encoded2 = self.encoder2(x)
    decoded2 = self.decoder2(encoded2)
    return decoded2

autoencoder2 = Autoencoder2(latent_dim)

# %%
x_train_200 = autoencoder1.encoder1.predict(x_train).reshape(60000, 20, 10)
x_test_200 = autoencoder1.encoder1.predict(x_test).reshape(10000, 20, 10)

# %%
autoencoder2.compile(optimizer='RMSprop', loss=losses.MeanSquaredError(), metrics=['accuracy'])

# %%
autoencoder2.fit(x_train_200, x_train_200,
                epochs=100,
                batch_size=100,
                shuffle=True,
                validation_split=0.3)
# Out:
# Epoch 1/100
# 420/420 [==============================] - 4s 6ms/step - loss: 0.1793 - accuracy: 0.4797 - val_loss: 0.0862 - val_accuracy: 0.6573
# Epoch 2/100
# 420/420 [==============================] - 2s 5ms/step - loss: 0.0818 - accuracy: 0.6734 - val_loss: 0.0718 - val_accuracy: 0.6988
# Epoch 3/100
# 420/420 [==============================] - 2s 5ms/step - loss: 0.0711 - accuracy: 0.7057 - val_loss: 0.0670 - val_accuracy: 0.7105
# Epoch 4/100
# 420/420 [==============================] - 2s 5ms/step - loss: 0.0670 - accuracy: 0.7168 - val_loss: 0.0648 - val_accuracy: 0.7205
# Epoch 5/100
# 420/420 [==============================] - 2s 5ms/step - loss: 0.0646 - accuracy: 0.7231 - val_loss: 0.0623 - val_accuracy: 0.7230
# Epoch 6/100
# 420/420 [==============================] - 2s 5ms/step - loss: 0.0626 - accuracy: 0.7273 - val_loss: 0.0613 - val_accuracy: 0.7292
# Epoch 7/100
# 420/420 [==============================] - 2s 5ms/step - loss: 0.0613 - accuracy: 0.7296 - val_loss: 0.0587 - val_accuracy: 0.7302
# Epoch 8/100
# 420/420 [==============================] - 2s 5ms/step - loss: 0.0590 - accuracy: 0.7325 - val_loss: 0.0581 - val_accuracy: 0.7333
# Epoch 9/100
# 420/420 [==============================] - 2s 5ms/step - loss: 0.0588 - accuracy: 0.7332 - val_loss: 0.0578 - val_accuracy: 0.7348
# Epoch 10/100
# 420/420 [==============================] - 2s 5ms/step - loss: 0.0570 - accuracy: 0.7398 - val_loss: 0.0564 - val_accuracy: 0.7392
# Epoch 87/100
# 420/420 [==============================] - 2s 5ms/step - loss: 0.0569 - accuracy: 0.7399 - val_loss: 0.0562 - val_accuracy: 0.7395
# Epoch 88/100
# 420/420 [==============================] - 2s 5ms/step - loss: 0.0570 - accuracy: 0.7399 - val_loss: 0.0571 - val_accuracy: 0.7361
# Epoch 89/100
# 420/420 [==============================] - 2s 5ms/step - loss: 0.0569 - accuracy: 0.7388 - val_loss: 0.0565 - val_accuracy: 0.7368
# Epoch 90/100
# 420/420 [==============================] - 2s 5ms/step - loss: 0.0567 - accuracy: 0.7400 - val_loss: 0.0567 - val_accuracy: 0.7371
# Epoch 91/100
# 420/420 [==============================] - 2s 5ms/step - loss: 0.0562 - accuracy: 0.7403 - val_loss: 0.0475 - val_accuracy: 0.7447
# Epoch 92/100
# 420/420 [==============================] - 2s 5ms/step - loss: 0.0470 - accuracy: 0.7483 - val_loss: 0.0459 - val_accuracy: 0.7495
# Epoch 93/100
# 420/420 [==============================] - 2s 5ms/step - loss: 0.0462 - accuracy: 0.7492 - val_loss: 0.0461 - val_accuracy: 0.7482
# Epoch 94/100
# 420/420 [==============================] - 2s 5ms/step - loss: 0.0461 - accuracy: 0.7508 - val_loss: 0.0462 - val_accuracy: 0.7480
# Epoch 95/100
# 420/420 [==============================] - 2s 5ms/step - loss: 0.0459 - accuracy: 0.7505 - val_loss: 0.0465 - val_accuracy: 0.7466
# Epoch 96/100
# 420/420 [==============================] - 2s 5ms/step - loss: 0.0459 - accuracy: 0.7507 - val_loss: 0.0456 - val_accuracy: 0.7496
# Epoch 97/100
# 420/420 [==============================] - 2s 5ms/step - loss: 0.0457 - accuracy: 0.7508 - val_loss: 0.0457 - val_accuracy: 0.7507
# Epoch 98/100
# 420/420 [==============================] - 2s 5ms/step - loss: 0.0458 - accuracy: 0.7518 - val_loss: 0.0458 - val_accuracy: 0.7489
# Epoch 99/100
# 420/420 [==============================] - 2s 5ms/step - loss: 0.0457 - accuracy: 0.7511 - val_loss: 0.0458 - val_accuracy: 0.7486
# Epoch 100/100
# 420/420 [==============================] - 2s 5ms/step - loss: 0.0458 - accuracy: 0.7516 - val_loss: 0.0458 - val_accuracy: 0.7497

# %%
plt.plot(autoencoder2.history.history['val_accuracy'])

# %%
encoded_imgs = autoencoder2.encoder2(x_test_200).numpy()
decoded_imgs = autoencoder2.decoder2(encoded_imgs).numpy()

# %%
n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
  # display original
  ax = plt.subplot(3, n, i + 1)
  plt.imshow(x_test[i])
  plt.title("original")
  plt.gray()
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

  # display encoded images
  ax = plt.subplot(3, n, i + 1 + n)
  plt.imshow(encoded_imgs[i].reshape(9,5))
  plt.title("encoded")
  plt.gray()
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

  # display reconstruction
  ax = plt.subplot(3, n, i + 1 + n*2)
  plt.imshow(decoded_imgs[i])
  plt.title("reconstructed")
  plt.gray()
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

plt.show()

# %%
for layer in autoencoder2.layers:
    weights = layer.get_weights()
    
fig, axs = plt.subplots(2, 3)
axs[0, 0].imshow(weights[0][0].reshape(20, 10))
axs[0, 1].imshow(weights[0][7].reshape(20, 10))
axs[0, 2].imshow(weights[0][21].reshape(20, 10))
axs[1, 0].imshow(weights[0][30].reshape(20, 10))
axs[1, 1].imshow(weights[0][36].reshape(20, 10))
axs[1, 2].imshow(weights[0][42].reshape(20, 10))

plt.show()

# %% [markdown]
# # Reduce Unit Size from 45 to 10

# %%
ys_train = np.zeros((60000,10))
for i in range(0, 60000):
    for j in range(0, 10):
        curr_digit = y_train[i]
        if (j==curr_digit):
            ys_train[i, j] = 1

# %%
ys_test = np.zeros((10000,10))
for i in range(0, 10000):
    for j in range(0, 10):
        curr_digit = y_test[i]
        if (j==curr_digit):
            ys_test[i, j] = 1

# %%
latent_dim = 15

class Autoencoder3(Model):
  def __init__(self, latent_dim):
    super(Autoencoder3, self).__init__()
    self.latent_dim3 = latent_dim   
    self.encoder3 = tf.keras.Sequential([
      layers.Flatten(),
      layers.Dense(latent_dim, activation='relu'),
    ])
    self.decoder3 = tf.keras.Sequential([
      layers.Dense(10, activation='softmax'),
    ])

  def call(self, x):
    encoded3 = self.encoder3(x)
    decoded3 = self.decoder3(encoded3)
    return decoded3

autoencoder3 = Autoencoder3(latent_dim)

# %%
x_train_45 = autoencoder2.encoder2.predict(x_train_200).reshape(60000, 9, 5)
x_test_45 = autoencoder2.encoder2.predict(x_test_200).reshape(10000, 9, 5)

# %%
autoencoder3.compile(optimizer='RMSprop', loss=losses.MeanSquaredError(), metrics=['accuracy'])

# %%
autoencoder3.fit(x_train_45, ys_train,
                epochs=100,
                batch_size=100,
                shuffle=True,
                validation_split=0.3)
# Out:
# Epoch 1/100
# 420/420 [==============================] - 4s 5ms/step - loss: 0.0775 - accuracy: 0.3481 - val_loss: 0.0350 - val_accuracy: 0.8029
# Epoch 2/100
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0312 - accuracy: 0.8219 - val_loss: 0.0220 - val_accuracy: 0.8637
# Epoch 3/100
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0213 - accuracy: 0.8695 - val_loss: 0.0188 - val_accuracy: 0.8791
# Epoch 4/100
# 420/420 [==============================] - 1s 4ms/step - loss: 0.0188 - accuracy: 0.8798 - val_loss: 0.0173 - val_accuracy: 0.8879
# Epoch 5/100
# 420/420 [==============================] - 1s 2ms/step - loss: 0.0172 - accuracy: 0.8916 - val_loss: 0.0164 - val_accuracy: 0.8914
# Epoch 6/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.0160 - accuracy: 0.8973 - val_loss: 0.0157 - val_accuracy: 0.8974
# Epoch 7/100
# Epoch 46/100
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0124 - accuracy: 0.9189 - val_loss: 0.0127 - val_accuracy: 0.9158
# Epoch 47/100
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0123 - accuracy: 0.9203 - val_loss: 0.0126 - val_accuracy: 0.9168
# Epoch 48/100
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0123 - accuracy: 0.9192 - val_loss: 0.0127 - val_accuracy: 0.9161
# Epoch 49/100
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0123 - accuracy: 0.9194 - val_loss: 0.0126 - val_accuracy: 0.9176
# Epoch 50/100
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0120 - accuracy: 0.9215 - val_loss: 0.0128 - val_accuracy: 0.9157
# Epoch 51/100
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0121 - accuracy: 0.9223 - val_loss: 0.0125 - val_accuracy: 0.9169
# Epoch 52/100
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0120 - accuracy: 0.9205 - val_loss: 0.0124 - val_accuracy: 0.9166
# Epoch 53/100
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0119 - accuracy: 0.9222 - val_loss: 0.0125 - val_accuracy: 0.9171
# Epoch 54/100
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0119 - accuracy: 0.9221 - val_loss: 0.0125 - val_accuracy: 0.9171
# Epoch 55/100
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0118 - accuracy: 0.9230 - val_loss: 0.0123 - val_accuracy: 0.9188
# Epoch 56/100
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0118 - accuracy: 0.9232 - val_loss: 0.0124 - val_accuracy: 0.9174
# Epoch 57/100
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0119 - accuracy: 0.9233 - val_loss: 0.0124 - val_accuracy: 0.9179
# Epoch 58/100
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0117 - accuracy: 0.9247 - val_loss: 0.0124 - val_accuracy: 0.9192
# Epoch 59/100
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0116 - accuracy: 0.9239 - val_loss: 0.0122 - val_accuracy: 0.9196
# Epoch 60/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.0116 - accuracy: 0.9250 - val_loss: 0.0123 - val_accuracy: 0.9186
# Epoch 61/100
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0120 - accuracy: 0.9215 - val_loss: 0.0123 - val_accuracy: 0.9190
# Epoch 62/100
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0117 - accuracy: 0.9237 - val_loss: 0.0123 - val_accuracy: 0.9196
# Epoch 63/100
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0115 - accuracy: 0.9246 - val_loss: 0.0122 - val_accuracy: 0.9202
# Epoch 64/100
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0118 - accuracy: 0.9240 - val_loss: 0.0122 - val_accuracy: 0.9198
# Epoch 84/100
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0112 - accuracy: 0.9267 - val_loss: 0.0118 - val_accuracy: 0.9228
# Epoch 85/100
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0110 - accuracy: 0.9298 - val_loss: 0.0116 - val_accuracy: 0.9239
# Epoch 86/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.0111 - accuracy: 0.9285 - val_loss: 0.0117 - val_accuracy: 0.9231
# Epoch 87/100
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0108 - accuracy: 0.9307 - val_loss: 0.0118 - val_accuracy: 0.9231
# Epoch 88/100
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0109 - accuracy: 0.9295 - val_loss: 0.0116 - val_accuracy: 0.9240
# Epoch 89/100
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0111 - accuracy: 0.9279 - val_loss: 0.0117 - val_accuracy: 0.9228
# Epoch 90/100
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0108 - accuracy: 0.9314 - val_loss: 0.0116 - val_accuracy: 0.9239
# Epoch 91/100
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0107 - accuracy: 0.9296 - val_loss: 0.0117 - val_accuracy: 0.9232
# Epoch 92/100
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0109 - accuracy: 0.9295 - val_loss: 0.0114 - val_accuracy: 0.9244
# Epoch 93/100
# 420/420 [==============================] - 2s 5ms/step - loss: 0.0107 - accuracy: 0.9313 - val_loss: 0.0115 - val_accuracy: 0.9243
# Epoch 94/100
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0111 - accuracy: 0.9278 - val_loss: 0.0114 - val_accuracy: 0.9254
# Epoch 95/100
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0107 - accuracy: 0.9309 - val_loss: 0.0116 - val_accuracy: 0.9241
# Epoch 96/100
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0107 - accuracy: 0.9307 - val_loss: 0.0114 - val_accuracy: 0.9255
# Epoch 97/100
# 420/420 [==============================] - 2s 5ms/step - loss: 0.0105 - accuracy: 0.9317 - val_loss: 0.0114 - val_accuracy: 0.9254
# Epoch 98/100
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0106 - accuracy: 0.9299 - val_loss: 0.0113 - val_accuracy: 0.9258
# Epoch 99/100
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0108 - accuracy: 0.9307 - val_loss: 0.0113 - val_accuracy: 0.9259
# Epoch 100/100
# 420/420 [==============================] - 1s 4ms/step - loss: 0.0108 - accuracy: 0.9298 - val_loss: 0.0115 - val_accuracy: 0.9240

# %%
plt.plot(autoencoder3.history.history['val_accuracy'])

# %%
results = autoencoder3.evaluate(x_test_45, ys_test, batch_size=128)
print(results)
# Out:
# 79/79 [==============================] - 1s 3ms/step - loss: 0.0109 - accuracy: 0.9291
# [0.010920661501586437, 0.929099977016449]
